# %%
import pandas as pd
import matplotlib.pyplot as plt
# Make sure plots show up in notebooks
# %matplotlib inline

surveys_df = pd.read_csv("data/surveys.csv")

# %%
my_plot = surveys_df.plot("hindfoot_length","weight", kind="scatter")

# %%
# plot a histogram of weights
#myfilter = surveys_df.groupby('weight')
histogram = surveys_df.plot(0,'weight',kind='hist')
histogram.set_ylabel('count')
histogram.set_xlabel('10 bins of weight')
# Out:
# Text(0.5, 0, '10 bins of weight')

# %%
surveys_df.hist('weight')
plt.ylabel('count')
plt.xlabel('weight')
plt.show()

# %%
histogram =surveys_df.hist('weight',bins=10, grid=False)
